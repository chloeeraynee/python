# %%
# feb 20 2025
# chloe rayne ibarra
# exploratory/preliminary analysis of national salary data by gender

# %%
# adding necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# pasting in national salary data from the bureau of labor statistics
all_data = [
[2014,796,780,790,799],
[2015,808,801,803,825],
[2016,830,824,827,849],
[2017,865,859,859,857],
[2018,881,876,887,900],
[2019,905,908,919,936],
[2020,957,1002,994,984],
[2021,989,990,1001,1010],
[2022,1037,1041,1070,1085],
[2023,1100,1100,1118,1145],
[2024,1139,1143,1165,1192]
]
men_data = [
[2014,872,857,870,882],
[2015,895,886,889,907],
[2016,912,909,911,927],
[2017,950,934,937,946],
[2018,965,959,973,993],
[2019,1004,1000,1002,1022],
[2020,1066,1087,1104,1072],
[2021,1089,1094,1100,1103],
[2022,1128,1144,1164,1176],
[2023,1186,1181,1208,1231],
[2024,1227,1253,1264,1302]
]
women_data = [
[2014,722,716,715,724],
[2015,730,726,721,729],
[2016,750,744,745,758],
[2017,765,780,767,769],
[2018,783,780,796,794],
[2019,806,814,825,843],
[2020,857,913,902,894],
[2021,900,899,916,930],
[2022,939,943,971,975],
[2023,996,993,1005,1031],
[2024,1021,1017,1054,1083]
]

# defining the column names
col = ['Year', 'Qtr1', 'Qtr2', 'Qtr3', 'Qtr4']

# defining the separate dataframes
all = pd.DataFrame(all_data, columns=col)
men = pd.DataFrame(men_data, columns=col)
women = pd.DataFrame(women_data, columns=col)
# Out:
#    Year  Qtr1  Qtr2  Qtr3  Qtr4
# 0  2014   722   716   715   724
# 1  2015   730   726   721   729
# 2  2016   750   744   745   758
# 3  2017   765   780   767   769
# 4  2018   783   780   796   794

# %%
# viewing the top 5 rows of the dataframes
all.head(5)
# Out:
#    Year  Qtr1  Qtr2  Qtr3  Qtr4
# 0  2014   796   780   790   799
# 1  2015   808   801   803   825
# 2  2016   830   824   827   849
# 3  2017   865   859   859   857
# 4  2018   881   876   887   900

# %%
men.head(5)
# Out:
#    Year  Qtr1  Qtr2  Qtr3  Qtr4
# 0  2014   872   857   870   882
# 1  2015   895   886   889   907
# 2  2016   912   909   911   927
# 3  2017   950   934   937   946
# 4  2018   965   959   973   993

# %%
women.head(5)
# Out:
#    Year  Qtr1  Qtr2  Qtr3  Qtr4
# 0  2014   722   716   715   724
# 1  2015   730   726   721   729
# 2  2016   750   744   745   758
# 3  2017   765   780   767   769
# 4  2018   783   780   796   794

# %%
# getting descriptive statistics for prelimiary analysis
all.describe()
# Out:
#               Year         Qtr1         Qtr2         Qtr3         Qtr4
# count    11.000000    11.000000    11.000000    11.000000    11.000000
# mean   2019.000000   842.636364   847.727273   856.090909   866.363636
# std       3.316625   107.174878   109.070703   119.689143   125.216830
# min    2014.000000   722.000000   716.000000   715.000000   724.000000
# 25%    2016.500000   757.500000   762.000000   756.000000   763.500000
# 50%    2019.000000   806.000000   814.000000   825.000000   843.000000
# 75%    2021.500000   919.500000   928.000000   943.500000   952.500000
# max    2024.000000  1021.000000  1017.000000  1054.000000  1083.000000

# %%
men.describe()
# Out:
#               Year         Qtr1         Qtr2         Qtr3         Qtr4
# count    11.000000    11.000000    11.000000    11.000000    11.000000
# mean   2019.000000  1026.727273  1027.636364  1038.363636  1051.000000
# std       3.316625   120.756856   131.633030   136.501482   139.310445
# min    2014.000000   872.000000   857.000000   870.000000   882.000000
# 25%    2016.500000   931.000000   921.500000   924.000000   936.500000
# 50%    2019.000000  1004.000000  1000.000000  1002.000000  1022.000000
# 75%    2021.500000  1108.500000  1119.000000  1134.000000  1139.500000
# max    2024.000000  1227.000000  1253.000000  1264.000000  1302.000000

# %%
women.describe()
# Out:
#               Year         Qtr1         Qtr2         Qtr3         Qtr4
# count    11.000000    11.000000    11.000000    11.000000    11.000000
# mean   2019.000000   842.636364   847.727273   856.090909   866.363636
# std       3.316625   107.174878   109.070703   119.689143   125.216830
# min    2014.000000   722.000000   716.000000   715.000000   724.000000
# 25%    2016.500000   757.500000   762.000000   756.000000   763.500000
# 50%    2019.000000   806.000000   814.000000   825.000000   843.000000
# 75%    2021.500000   919.500000   928.000000   943.500000   952.500000
# max    2024.000000  1021.000000  1017.000000  1054.000000  1083.000000

# %%
# ignoring Year statistics since they hold no significant meaning to our analysis
# overall, the mean for all qtrs for the men is about 175 dollars higher than the women (~1025 to ~850)
# the mean for all salary earners is around ~850, which is the same mean for women
